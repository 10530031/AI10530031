# %%
# plot image
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('dog-2238012_960_720.jpg') 
plt.imshow(img)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "/content/drive/My Drive/"
# Out:
#  001	 'Colab Notebooks'   Music	     資訊應用與服務學習.ppt
#  1119	  DCIM		     Timer.pptx
#  aa	  Iphone	     @@@@.txt
#  Animal  'Maple story'	     企劃寫作.pptx

# %%
cd "/content/drive/My Drive/aa/"
# Out:
# /content/drive/My Drive/aa

# %%
# !ls
# Out:
# 7474.png  abcd.ipynb

# %%
# plot image
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('7474.png') 
plt.imshow(img)

plt.show()
